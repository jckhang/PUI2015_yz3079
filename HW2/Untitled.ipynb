# %%
import json
from __future__ import print_function

# %%
with open('B67.json', 'rb') as jfile:
    jdata = json.load(jfile)

# %%
st='test.txt'
fi=open(st,'wb')
print('helloworld', file=fi)
print('hello','pi', file=fi)

# %%
print jdata['Siri']['ServiceDelivery']
# Out:
# {u'SituationExchangeDelivery': [], u'ResponseTimestamp': u'2015-10-18T22:04:45.539-04:00', u'VehicleMonitoringDelivery': [{u'VehicleActivity': [{u'RecordedAtTime': u'2015-10-18T22:04:36.000-04:00', u'MonitoredVehicleJourney': {u'OriginRef': u'MTA_306337', u'Bearing': 329.1962, u'VehicleLocation': {u'Latitude': 40.656058, u'Longitude': -73.981609}, u'SituationRef': [], u'OperatorRef': u'MTA NYCT', u'VehicleRef': u'MTA NYCT_426', u'BlockRef': u'MTA NYCT_JG_D5-Sunday_D_JG_42540_B6769-5', u'DestinationName': u'KENSINGTON CORTLYOU RD', u'DestinationRef': u'MTA_801044', u'JourneyPatternRef': u'MTA_B670107', u'MonitoredCall': {u'VisitNumber': 1, u'StopPointRef': u'MTA_306574', u'ExpectedDepartureTime': u'2015-10-18T22:04:58.510-04:00', u'StopPointName': u'10 AV/20 ST', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 6241.32, u'StopsFromCall': 0, u'PresentableDistance': u'approaching', u'DistanceFromCall': 110.61}}, u'ExpectedArrivalTime': u'2015-10-18T22:04:58.510-04:00'}, u'LineR
# ...
